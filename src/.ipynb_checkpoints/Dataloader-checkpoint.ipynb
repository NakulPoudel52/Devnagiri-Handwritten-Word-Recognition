# %%
import codecs
import numpy as np
import os

# %%
with codecs.open('/home/nakul/Documents/Major/Devnagari-Handwritten-Word-Recongition-with-Deep-Learning/data/full.txt', "r", encoding='utf-8') as f:
    lines = f.readlines()

# %%
lines #an array is created
# Out:
# ['\ufeff\r\n',
#  'HindiSeg/train/10/259/1.jpg हांगकांग\r\n',
#  'HindiSeg/train/10/259/2.jpg लिलेश्वर\r\n',
#  'HindiSeg/train/10/259/3.jpg आयडीन\r\n',
#  'HindiSeg/train/10/259/4.jpg सिखावन\r\n',
#  'HindiSeg/train/10/259/5.jpg विकिपीडिया\r\n',
#  'HindiSeg/train/10/259/6.jpg याचिका\r\n',
#  'HindiSeg/train/10/259/7.jpg निहलानी\r\n',
#  'HindiSeg/train/10/259/8.jpg चिकित्सक\r\n',
#  'HindiSeg/train/10/259/9.jpg उषा\r\n',
#  'HindiSeg/train/10/259/10.jpg गोविंदम\r\n',
#  'HindiSeg/train/10/259/11.jpg हराकर\r\n',
#  'HindiSeg/train/10/259/12.jpg कहूँ\r\n',
#  'HindiSeg/train/10/259/13.jpg आर्किटेक्ट\r\n',
#  'HindiSeg/train/10/259/14.jpg वार्ष्णेय\r\n',
#  'HindiSeg/train/10/259/15.jpg काले\r\n',
#  'HindiSeg/train/10/259/16.jpg एजुकेशन\r\n',
#  'HindiSeg/train/10/259/17.jpg झटका\r\n',
#  'HindiSeg/train/10/259/18.jpg बोला-मैँने\r\n',
#  'HindiSeg/train/10/259/19.jpg चौरसिया\r\n',
#  'HindiSeg/train/10/259/20.jpg एनीमिज्म\r\n',
#  'HindiSeg/train/10/259/21.jpg बनते\r\n',
#  'HindiSeg/train/10/259/22.jpg बताए\r\n',
#  'HindiSeg/train/10/259/23.jpg घीसादास\r\n',
#  'HindiSeg/train/10/259/24.jpg कथानक\r\n',
#  'HindiSeg/train/10/259/25.jpg मांजने\r\n',
#  'HindiSeg/train/10/259/26.jpg सुनसरी\r\n',
#  'HindiSeg/train/10/259/27.jpg भगवत्स्वरूप\r\n',
#  'HindiSeg/train/10/259/28.jpg लम्हा\r\n',
#  'HindiSeg/train/10/259/29.jpg धृतराष्ट्र\r\n',
#  'HindiSeg/train/10/259/30.jpg वयोवृद्ध\r\n',
#  'HindiSeg/train/10/259/31.jpg बादलों\r\n',
#  'HindiSeg/train/10/259/32.jpg टोकती\r\n',
#  'HindiSeg/train/10/259/33.jpg मेक\r\n',
#  'HindiSeg/train/10/259/34.jpg वरदानों\r\n',
#  'HindiSeg/train/10/259/35.jpg युवा\r\n',
#  'HindiSeg/train/10/259/36.jpg बुद्ध\r\n',
#  'HindiSeg/train/10/3/1.jpg अभ्यावेदनों\r\n',
#  'HindiSeg/train/10/3/2.jpg पस्तौल\r\n',
#  'HindiSeg/train/10/3/3.jpg आशा\r\n',
#  'HindiSeg/train/10/3/4.jpg झाड़\r\n',
#  'HindiSeg/train/10/3/5.jpg रीमखोली\r\n',
#  'HindiSeg/train/10/3/6.jpg गुलगुले\r\n',
#  'HindiSeg/train/10/3/7.jpg मृतका\r\n',
#  'HindiSeg/train/10/3/8.jpg टरका\r\n',
#  'HindiSeg/train/10/3/9.jpg संपादन\r\n',
#  'HindiSeg/train/10/3/10.jpg १६३२\r\n',
#  'HindiSeg/train/10/3/11.jpg दिखाती\r\n',
#  'HindiSeg/train/10/3/12.jpg छठ\r\n',
#  'HindiSeg/train/10/3/13.jpg समूचे\r\n',
#  'HindiSeg/train/10/3/14.jpg ज्ञानजी\r\n',
#  'HindiSeg/train/10/3/15.jpg अनसुनी\r\n',
#  'HindiSeg/train/10/3/16.jpg फायनल\r\n',
#  'HindiSeg/train/10/3/17.jpg मंत्रालय\r\n',
#  'HindiSeg/train/10/3/18.jpg डबला\r\n',
#  'HindiSeg/train/10/3/19.jpg प्रभावपूण्र\r\n',
#  'HindiSeg/train/10/3/20.jpg रन\r\n',
#  'HindiSeg/train/10/3/21.jpg मजमा\r\n',
#  'HindiSeg/train/10/3/22.jpg प्रारूपण\r\n',
#  'HindiSeg/train/10/3/23.jpg राषट्रपति\r\n',
#  'HindiSeg/train/10/3/24.jpg महासभा\r\n',
#  'HindiSeg/train/10/3/25.jpg जोड़ी\r\n',
#  'HindiSeg/train/10/3/26.jpg नालंदा\r\n',
#  'HindiSeg/train/10/3/27.jpg महालक्ष्म्यै\r\n',
#  'HindiSeg/train/10/3/28.jpg जीवांश\r\n',
#  'HindiSeg/train/10/3/29.jpg महायुद्ध\r\n',
#  'HindiSeg/train/10/3/30.jpg आगरा\r\n',
#  'HindiSeg/train/10/3/31.jpg पायेगा\r\n',
#  'HindiSeg/train/10/3/32.jpg हंसता\r\n',
#  'HindiSeg/train/10/3/33.jpg सत्संगति\r\n',
#  'HindiSeg/train/10/3/34.jpg पिक्चर\r\n',
#  'HindiSeg/train/10/3/35.jpg पंक्ति\r\n',
#  'HindiSeg/train/10/3/36.jpg रुलाया\r\n',
#  'HindiSeg/train/10/3/37.jpg हबल\r\n',
#  'HindiSeg/train/10/3/38.jpg भागे\r\n',
#  'HindiSeg/train/10/3/39.jpg ओझा\r\n',
#  'HindiSeg/train/10/67/1.jpg बेच\r\n',
#  'HindiSeg/train/10/67/2.jpg गोडसे\r\n',
#  'HindiSeg/train/10/67/3.jpg दरख्तों\r\n',
#  'HindiSeg/train/10/67/4.jpg रूबरू\r\n',
#  'HindiSeg/train/10/67/5.jpg काला\r\n',
#  'HindiSeg/train/10/67/6.jpg मंचों\r\n',
#  'HindiSeg/train/10/67/7.jpg जरूरीः\r\n',
#  'HindiSeg/train/10/67/8.jpg बाल्यकाल\r\n',
#  'HindiSeg/train/10/67/9.jpg क़व्वाली\r\n',
#  'HindiSeg/train/10/67/10.jpg अमरता\r\n',
#  'HindiSeg/train/10/67/11.jpg इंटर\r\n',
#  'HindiSeg/train/10/67/12.jpg चाल\r\n',
#  'HindiSeg/train/10/67/13.jpg मेज\r\n',
#  'HindiSeg/train/10/67/14.jpg चेन्नेई\r\n',
#  'HindiSeg/train/10/67/15.jpg जाती\r\n',
#  'HindiSeg/train/10/129/6.jpg अघोर\r\n',
#  'HindiSeg/train/10/129/7.jpg टिका\r\n',
#  'HindiSeg/train/10/129/8.jpg पहियों\r\n',
#  'HindiSeg/train/10/129/9.jpg मालाएं\r\n',
#  'HindiSeg/train/10/129/10.jpg हाड़-मांस\r\n',
#  'HindiSeg/train/10/129/11.jpg कटती\r\n',
#  'HindiSeg/train/10/129/12.jpg खिलाफ़\r\n',
#  'HindiSeg/train/10/129/13.jpg अधिनियम।\r\n',
#  'HindiSeg/train/10/129/14.jpg उसमें\r\n',
#  'HindiSeg/train/10/129/15.jpg सुपारी\r\n',
#  'HindiSeg/train/10/129/16.jpg शब्दावली\r\n',
#  'HindiSeg/train/10/129/17.jpg उनको\r\n',
#  'HindiSeg/train/10/129/18.jpg कुछेक\r\n',
#  'HindiSeg/train/10/129/19.jpg साझेदार\r\n',
#  'HindiSeg/train/10/129/20.jpg वास्तविकता\r\n',
#  'HindiSeg/train/10/129/21.jpg बैठें\r\n',
#  'HindiSeg/train/10/129/22.jpg बुझने\r\n',
#  'HindiSeg/train/10/129/23.jpg पालकी\r\n',
#  'HindiSeg/train/10/129/24.jpg स्वामिभक्ति\r\n',
#  'HindiSeg/train/10/129/25.jpg वृतांत\r\n',
#  'HindiSeg/train/10/129/26.jpg ओवर\r\n',
#  'HindiSeg/train/10/129/27.jpg गौतमी\r\n',
#  'HindiSeg/train/10/129/28.jpg स्व\r\n',
#  'HindiSeg/train/10/129/29.jpg गिराए\r\n',
#  'HindiSeg/train/10/129/30.jpg कटाई\r\n',
#  'HindiSeg/train/10/129/31.jpg दौरे\r\n',
#  'HindiSeg/train/10/129/32.jpg अध्यक्षता\r\n',
#  'HindiSeg/train/10/129/33.jpg स्मृतियाँ\r\n',
#  'HindiSeg/train/10/129/34.jpg समक्ष\r\n',
#  'HindiSeg/train/10/129/35.jpg शराबी\r\n',
#  'HindiSeg/train/10/129/36.jpg सुशांत\r\n',
#  'HindiSeg/train/10/129/37.jpg पठार\r\n',
#  'HindiSeg/train/10/129/38.jpg कैसी\r\n',
#  'HindiSeg/train/10/110/1.jpg घायलों\r\n',
#  'HindiSeg/train/10/110/2.jpg अभिषेक\r\n',
#  'HindiSeg/train/10/110/3.jpg पंचायत\r\n',
#  'HindiSeg/train/10/110/4.jpg रोशनदानों\r\n',
#  'HindiSeg/train/10/110/5.jpg लड़का\r\n',
#  'HindiSeg/train/10/110/6.jpg रक्षक\r\n',
#  'HindiSeg/train/10/110/7.jpg विजयलक्ष्मी\r\n',
#  'HindiSeg/train/10/110/8.jpg डू\r\n',
#  'HindiSeg/train/10/110/9.jpg कायल\r\n',
#  'HindiSeg/train/10/110/10.jpg उन्हों\r\n',
#  'HindiSeg/train/10/110/11.jpg अटैक\r\n',
#  'HindiSeg/train/10/110/12.jpg छिनकर\r\n',
#  'HindiSeg/train/10/110/13.jpg भक्ति।\r\n',
#  'HindiSeg/train/10/110/14.jpg आवष्यकता\r\n',
#  'HindiSeg/train/10/110/15.jpg घटना\r\n',
#  'HindiSeg/train/10/110/16.jpg मिनीलास\r\n',
#  'HindiSeg/train/10/110/17.jpg खड़ीबोली\r\n',
#  'HindiSeg/train/10/110/18.jpg गहने\r\n',
#  'HindiSeg/train/10/110/19.jpg काबिज\r\n',
#  'HindiSeg/train/10/110/20.jpg उत्प्रेरित\r\n',
#  'HindiSeg/train/10/110/21.jpg डिस्को\r\n',
#  'HindiSeg/train/10/110/22.jpg मंडी\r\n',
#  'HindiSeg/train/10/110/23.jpg क्षणिक\r\n',
#  'HindiSeg/train/10/110/24.jpg ख-आन\r\n',
#  'HindiSeg/train/10/110/25.jpg आर्यभट\r\n',
#  'HindiSeg/train/10/110/26.jpg अशेष\r\n',
#  'HindiSeg/train/10/110/27.jpg स्टेडियम\r\n',
#  'HindiSeg/train/10/110/28.jpg ब्याह\r\n',
#  'HindiSeg/train/10/110/29.jpg भगतसिंह\r\n',
#  'HindiSeg/train/10/110/30.jpg रहमान\r\n',
#  'HindiSeg/train/10/110/31.jpg अनजान\r\n',
#  'HindiSeg/train/10/110/32.jpg रोगों\r\n',
#  'HindiSeg/train/10/110/33.jpg क्लेश\r\n',
#  'HindiSeg/train/10/110/34.jpg कण्ठे\r\n',
#  'HindiSeg/train/10/110/35.jpg अलगाना\r\n',
#  'HindiSeg/train/10/110/36.jpg बाजरा\r\n',
#  'HindiSeg/train/10/110/37.jpg निष्कपट\r\n',
#  'HindiSeg/train/10/110/38.jpg चूहे\r\n',
#  'HindiSeg/train/10/18/1.jpg पऊवि\r\n',
#  'HindiSeg/train/10/18/2.jpg दीपिका\r\n',
#  'HindiSeg/train/10/18/3.jpg चींची\r\n',
#  'HindiSeg/train/10/18/4.jpg जाना\r\n',
#  'HindiSeg/train/10/18/5.jpg बच्चियों\r\n',
#  'HindiSeg/train/10/18/6.jpg रिकमेंडेसन\r\n',
#  'HindiSeg/train/10/18/7.jpg वी\r\n',
#  'HindiSeg/train/10/18/8.jpg यादो\r\n',
#  'HindiSeg/train/10/18/9.jpg जुझारू\r\n',
#  'HindiSeg/train/10/18/10.jpg परिस्थितियों\r\n',
#  'HindiSeg/train/10/18/11.jpg ज्वैलरी\r\n',
#  'HindiSeg/train/10/18/12.jpg गवाई\r\n',
#  'HindiSeg/train/10/18/13.jpg प्रदर्शनकारियों\r\n',
#  'HindiSeg/train/10/18/14.jpg मिलिंद\r\n',
#  'HindiSeg/train/10/18/15.jpg ईश्वरत्व\r\n',
#  'HindiSeg/train/10/18/16.jpg जन्मोत्सव\r\n',
#  'HindiSeg/train/10/18/17.jpg नाहक\r\n',
#  'HindiSeg/train/10/18/18.jpg गेंदों\r\n',
#  'HindiSeg/train/10/18/19.jpg है-वहीं\r\n',
#  'HindiSeg/train/10/18/20.jpg पगली\r\n',
#  'HindiSeg/train/10/18/21.jpg मान\r\n',
#  'HindiSeg/train/10/18/22.jpg मुक्तिबोध\r\n',
#  'HindiSeg/train/10/18/23.jpg राष्टीय\r\n',
#  'HindiSeg/train/10/18/24.jpg साब\r\n',
#  'HindiSeg/train/10/18/25.jpg मैँ\r\n',
#  'HindiSeg/train/10/18/26.jpg रास\r\n',
#  'HindiSeg/train/10/18/27.jpg पदार्र्थो\r\n',
#  'HindiSeg/train/10/18/28.jpg ऑनली\r\n',
#  'HindiSeg/train/10/18/29.jpg वैज्ञानिकता\r\n',
#  'HindiSeg/train/10/18/30.jpg सुनाया।\r\n',
#  'HindiSeg/train/10/18/31.jpg कोच\r\n',
#  'HindiSeg/train/10/18/32.jpg उम्रकैद\r\n',
#  'HindiSeg/train/10/18/33.jpg अप्रचलित\r\n',
#  'HindiSeg/train/10/18/34.jpg तलाशी\r\n',
#  'HindiSeg/train/10/18/35.jpg सलामत\r\n',
#  'HindiSeg/train/10/18/36.jpg ज़मां\r\n',
#  'HindiSeg/train/10/18/37.jpg खंजर\r\n',
#  'HindiSeg/train/10/18/38.jpg कुरसी\r\n',
#  'HindiSeg/train/10/18/39.jpg हय।\r\n',
#  'HindiSeg/train/10/242/1.jpg हौसले\r\n',
#  'HindiSeg/train/10/242/2.jpg धनंजय\r\n',
#  'HindiSeg/train/10/242/3.jpg हेलीकोप्टर\r\n',
#  'HindiSeg/train/10/242/4.jpg डब्बा\r\n',
#  'HindiSeg/train/10/242/5.jpg वानखेड़े\r\n',
#  'HindiSeg/train/10/242/6.jpg जस्टिस\r\n',
#  'HindiSeg/train/10/242/7.jpg जनाधार\r\n',
#  'HindiSeg/train/10/242/8.jpg थीम\r\n',
#  'HindiSeg/train/10/242/9.jpg ५\r\n',
#  'HindiSeg/train/10/242/10.jpg पंच\r\n',
#  'HindiSeg/train/10/242/11.jpg स्कीम\r\n',
#  'HindiSeg/train/10/242/12.jpg प्लेटो\r\n',
#  'HindiSeg/train/10/242/13.jpg महिलाओ\r\n',
#  'HindiSeg/train/10/242/14.jpg खिलवाड़\r\n',
#  'HindiSeg/train/10/242/15.jpg परिवहन\r\n',
#  'HindiSeg/train/10/242/16.jpg रंजन-मोद\r\n',
#  'HindiSeg/train/10/242/17.jpg गंगा\r\n',
#  'HindiSeg/train/10/242/18.jpg ईवीएम\r\n',
#  'HindiSeg/train/10/242/19.jpg पारी\r\n',
#  'HindiSeg/train/10/242/20.jpg भर्तृहरि\r\n',
#  'HindiSeg/train/10/242/21.jpg झेल-झेलकर\r\n',
#  'HindiSeg/train/10/242/22.jpg अनुप्रयोग\r\n',
#  'HindiSeg/train/10/242/23.jpg डोर\r\n',
#  'HindiSeg/train/10/242/24.jpg मूर्च्छा\r\n',
#  'HindiSeg/train/10/242/25.jpg चार-पांच\r\n',
#  'HindiSeg/train/10/242/26.jpg हर्ष\r\n',
#  'HindiSeg/train/10/242/27.jpg आयोजकों\r\n',
#  'HindiSeg/train/10/242/28.jpg भाजपाईयों\r\n',
#  'HindiSeg/train/10/242/29.jpg क़ी\r\n',
#  'HindiSeg/train/10/242/30.jpg कंपती\r\n',
#  'HindiSeg/train/10/242/31.jpg अगस्त्य\r\n',
#  'HindiSeg/train/10/242/32.jpg तन\r\n',
#  'HindiSeg/train/10/242/33.jpg पंडीजी\r\n',
#  'HindiSeg/train/10/242/34.jpg तनातनी\r\n',
#  'HindiSeg/train/10/242/35.jpg गुरुर्ब्रह्मा\r\n',
#  'HindiSeg/train/10/242/36.jpg उलटे\r\n',
#  'HindiSeg/train/10/242/37.jpg कुछपल\r\n',
#  'HindiSeg/train/10/242/38.jpg करते।\r\n',
#  'HindiSeg/train/10/242/39.jpg मुझमें\r\n',
#  'HindiSeg/train/10/218/1.jpg बनती\r\n',
#  'HindiSeg/train/10/218/2.jpg मराठवाड़ा\r\n',
#  'HindiSeg/train/10/218/3.jpg ब्रायन\r\n',
#  'HindiSeg/train/10/218/4.jpg डॉ\r\n',
#  'HindiSeg/train/10/218/5.jpg निजाम\r\n',
#  'HindiSeg/train/10/218/6.jpg पसदिदा\r\n',
#  'HindiSeg/train/10/218/7.jpg आरोप\r\n',
#  'HindiSeg/train/10/218/8.jpg २५०००\r\n',
#  'HindiSeg/train/10/218/9.jpg कुम्हला\r\n',
#  'HindiSeg/train/10/218/10.jpg जाती।\r\n',
#  'HindiSeg/train/10/218/11.jpg मामाश्री\r\n',
#  'HindiSeg/train/10/218/12.jpg कहॉं\r\n',
#  'HindiSeg/train/10/218/13.jpg उपसमिति\r\n',
#  'HindiSeg/train/10/218/14.jpg समूचा\r\n',
#  'HindiSeg/train/10/218/15.jpg स्थूल\r\n',
#  'HindiSeg/train/10/218/16.jpg सुविधानुसार\r\n',
#  'HindiSeg/train/10/218/17.jpg घटिया\r\n',
#  'HindiSeg/train/10/218/18.jpg एयरलाईंस\r\n',
#  'HindiSeg/train/10/218/19.jpg रुकती\r\n',
#  'HindiSeg/train/10/218/20.jpg जुटाती\r\n',
#  'HindiSeg/train/10/218/21.jpg शवों\r\n',
#  'HindiSeg/train/10/218/22.jpg प्रभावशाली\r\n',
#  'HindiSeg/train/10/218/23.jpg गुज़रता\r\n',
#  'HindiSeg/train/10/218/24.jpg आएंगे\r\n',
#  'HindiSeg/train/10/218/25.jpg लिहाज़ा\r\n',
#  'HindiSeg/train/10/218/26.jpg भगा\r\n',
#  'HindiSeg/train/10/218/27.jpg शूटिंग\r\n',
#  'HindiSeg/train/10/218/28.jpg गर्मागर्म\r\n',
#  'HindiSeg/train/10/218/29.jpg भरतिया\r\n',
#  'HindiSeg/train/10/218/30.jpg उच्चारित\r\n',
#  'HindiSeg/train/10/218/31.jpg जन्मती\r\n',
#  'HindiSeg/train/10/218/32.jpg महेन्द्र\r\n',
#  'HindiSeg/train/10/218/33.jpg गावों-देहात\r\n',
#  'HindiSeg/train/10/218/34.jpg संभालता\r\n',
#  'HindiSeg/train/10/218/35.jpg दुर्भिक्ष\r\n',
#  'HindiSeg/train/10/218/36.jpg परिर्वन\r\n',
#  'HindiSeg/train/10/218/37.jpg शोक।\r\n',
#  'HindiSeg/train/10/218/38.jpg हॅसी\r\n',
#  'HindiSeg/train/10/188/1.jpg प्रधानतया\r\n',
#  'HindiSeg/train/10/188/2.jpg जाए\r\n',
#  'HindiSeg/train/10/188/3.jpg ग्रहों\r\n',
#  'HindiSeg/train/10/188/4.jpg पेपर्स\r\n',
#  'HindiSeg/train/10/188/5.jpg क्यूकी\r\n',
#  'HindiSeg/train/10/188/6.jpg अरमान\r\n',
#  'HindiSeg/train/10/188/7.jpg गुजरते\r\n',
#  'HindiSeg/train/10/188/8.jpg पढो\r\n',
#  'HindiSeg/train/10/188/9.jpg लाने-ले\r\n',
#  'HindiSeg/train/10/188/10.jpg गतिविधियों\r\n',
#  'HindiSeg/train/10/188/11.jpg शो\r\n',
#  'HindiSeg/train/10/188/12.jpg प्रसूता\r\n',
#  'HindiSeg/train/10/188/13.jpg बवेजा\r\n',
#  'HindiSeg/train/10/188/14.jpg ज़िंदगी\r\n',
#  'HindiSeg/train/10/188/15.jpg लेकर\r\n',
#  'HindiSeg/train/10/188/16.jpg नहा-धोकर\r\n',
#  'HindiSeg/train/10/188/17.jpg सीएम\r\n',
#  'HindiSeg/train/10/188/18.jpg कान्ट\r\n',
#  'HindiSeg/train/10/188/19.jpg कैम्रमेनों\r\n',
#  'HindiSeg/train/10/188/20.jpg अखाबारो\r\n',
#  'HindiSeg/train/10/188/21.jpg बगल\r\n',
#  'HindiSeg/train/10/188/22.jpg चर्चित\r\n',
#  'HindiSeg/train/10/188/23.jpg विचारणीय\r\n',
#  'HindiSeg/train/10/188/24.jpg उपक्रम\r\n',
#  'HindiSeg/train/10/188/25.jpg फूटा।\r\n',
#  'HindiSeg/train/10/188/26.jpg ऐबक\r\n',
#  'HindiSeg/train/10/188/27.jpg सजी-सजाई\r\n',
#  'HindiSeg/train/10/188/28.jpg रखवा\r\n',
#  'HindiSeg/train/10/188/29.jpg शुक्र\r\n',
#  'HindiSeg/train/10/188/30.jpg चन्द्रघन्टा\r\n',
#  'HindiSeg/train/10/188/31.jpg यॉर्क\r\n',
#  'HindiSeg/train/10/188/32.jpg विमर्श\r\n',
#  'HindiSeg/train/10/188/33.jpg नीचा\r\n',
#  'HindiSeg/train/10/188/34.jpg बिसेसर\r\n',
#  'HindiSeg/train/10/188/35.jpg पढ़ाई\r\n',
#  'HindiSeg/train/10/188/36.jpg दरवाजों\r\n',
#  'HindiSeg/train/10/188/37.jpg सम्मेलनों\r\n',
#  'HindiSeg/train/10/188/38.jpg वारदातों\r\n',
#  'HindiSeg/train/10/188/39.jpg दीर्घा\r\n',
#  'HindiSeg/train/10/188/40.jpg पीड़िता\r\n',
#  'HindiSeg/train/10/225/1.jpg देखकर\r\n',
#  'HindiSeg/train/10/225/2.jpg सौहार्द्रपूर्ण\r\n',
#  'HindiSeg/train/10/225/3.jpg विष्णुकांत\r\n',
#  'HindiSeg/train/10/225/4.jpg हालंकि\r\n',
#  'HindiSeg/train/10/225/5.jpg छोटा-छोटा\r\n',
#  'HindiSeg/train/10/225/6.jpg शुक्रिया\r\n',
#  'HindiSeg/train/10/225/7.jpg चिड़िया\r\n',
#  'HindiSeg/train/10/272/19.jpg जयराम\r\n',
#  'HindiSeg/train/10/272/20.jpg फेंकने\r\n',
#  'HindiSeg/train/10/272/21.jpg क्लाडियस\r\n',
#  'HindiSeg/train/10/272/22.jpg ज़ोर-शोर\r\n',
#  'HindiSeg/train/10/272/23.jpg कानूनगो\r\n',
#  'HindiSeg/train/10/272/24.jpg जितने\r\n',
#  'HindiSeg/train/10/272/25.jpg खो\r\n',
#  'HindiSeg/train/10/272/26.jpg ई-प्रशासन\r\n',
#  'HindiSeg/train/10/272/27.jpg धाँसू\r\n',
#  'HindiSeg/train/10/272/28.jpg फ्लोर\r\n',
#  'HindiSeg/train/10/272/29.jpg गढ़\r\n',
#  'HindiSeg/train/10/272/30.jpg युवकों\r\n',
#  'HindiSeg/train/10/272/31.jpg प्रचालक\r\n',
#  'HindiSeg/train/10/272/32.jpg डीएसपी\r\n',
#  'HindiSeg/train/10/272/33.jpg मुर्दाबाद\r\n',
#  'HindiSeg/train/10/272/34.jpg गृहिणियाँ\r\n',
#  'HindiSeg/train/10/272/35.jpg मोंटी\r\n',
#  'HindiSeg/train/10/272/36.jpg कालिमा\r\n',
#  'HindiSeg/train/10/272/37.jpg अच्छी\r\n',
#  'HindiSeg/train/10/272/38.jpg कस्बा\r\n',
#  'HindiSeg/train/10/272/39.jpg स्कंध\r\n',
#  'HindiSeg/train/10/238/1.jpg नायिकाएं\r\n',
#  'HindiSeg/train/10/238/2.jpg अभ्यर्थियों\r\n',
#  'HindiSeg/train/10/238/3.jpg इवेन\r\n',
#  'HindiSeg/train/10/238/4.jpg मंडराने\r\n',
#  'HindiSeg/train/10/238/5.jpg उलटा\r\n',
#  'HindiSeg/train/10/238/6.jpg डीपीआरओं\r\n',
#  'HindiSeg/train/10/238/7.jpg पक्की\r\n',
#  'HindiSeg/train/10/238/8.jpg अंदरूनी\r\n',
#  'HindiSeg/train/10/238/9.jpg सादे\r\n',
#  'HindiSeg/train/10/238/10.jpg संबन्धित\r\n',
#  'HindiSeg/train/10/238/11.jpg अकेले\r\n',
#  'HindiSeg/train/10/238/12.jpg अक्षांशीय\r\n',
#  'HindiSeg/train/10/238/13.jpg ११\r\n',
#  'HindiSeg/train/10/238/14.jpg खटीमा\r\n',
#  'HindiSeg/train/10/238/15.jpg दंगाईयो\r\n',
#  'HindiSeg/train/10/238/16.jpg कालकूट\r\n',
#  'HindiSeg/train/10/238/17.jpg प्रकाशकाधीन\r\n',
#  'HindiSeg/train/10/238/18.jpg जिक्र\r\n',
#  'HindiSeg/train/10/238/19.jpg प्रंशसा\r\n',
#  'HindiSeg/train/10/238/20.jpg मनीषा\r\n',
#  'HindiSeg/train/10/238/21.jpg मोटरसार्इकिल\r\n',
#  'HindiSeg/train/10/238/22.jpg सपने\r\n',
#  'HindiSeg/train/10/238/23.jpg थका-हारा\r\n',
#  'HindiSeg/train/10/238/24.jpg अपराधियों\r\n',
#  'HindiSeg/train/10/238/25.jpg पहचानिए\r\n',
#  'HindiSeg/train/10/238/26.jpg बच्चन\r\n',
#  'HindiSeg/train/10/238/27.jpg वृन्द\r\n',
#  'HindiSeg/train/10/238/28.jpg बज\r\n',
#  'HindiSeg/train/10/238/29.jpg अबू\r\n',
#  'HindiSeg/train/10/238/30.jpg मछलियों\r\n',
#  'HindiSeg/train/10/238/31.jpg निरंजन\r\n',
#  'HindiSeg/train/10/238/32.jpg तुच्छ\r\n',
#  'HindiSeg/train/10/238/33.jpg अवरोधों\r\n',
#  'HindiSeg/train/10/238/34.jpg रुझान\r\n',
#  'HindiSeg/train/10/238/35.jpg मौसी\r\n',
#  'HindiSeg/train/10/238/36.jpg प्रणव\r\n',
#  'HindiSeg/train/10/238/37.jpg वैधता\r\n',
#  'HindiSeg/train/10/222/1.jpg प्रेमसिंह\r\n',
#  'HindiSeg/train/10/222/2.jpg वीरप्पन\r\n',
#  'HindiSeg/train/10/222/3.jpg गिनवा\r\n',
#  'HindiSeg/train/10/222/4.jpg विस्लिंग\r\n',
#  'HindiSeg/train/10/222/5.jpg ध्वज\r\n',
#  'HindiSeg/train/10/222/6.jpg समर्पित\r\n',
#  'HindiSeg/train/10/222/7.jpg उभरे।\r\n',
#  'HindiSeg/train/10/222/8.jpg मीन\r\n',
#  'HindiSeg/train/10/222/9.jpg काटेगा\r\n',
#  'HindiSeg/train/10/222/10.jpg वार्ता\r\n',
#  'HindiSeg/train/10/222/11.jpg टाइट\r\n',
#  'HindiSeg/train/10/222/12.jpg जनन-क्षमता\r\n',
#  'HindiSeg/train/10/222/13.jpg कटकाई।\r\n',
#  'HindiSeg/train/10/222/14.jpg लिटल\r\n',
#  'HindiSeg/train/10/222/15.jpg केवलिया\r\n',
#  'HindiSeg/train/10/222/16.jpg मेढ़क\r\n',
#  'HindiSeg/train/10/222/17.jpg ख़रीदा।\r\n',
#  'HindiSeg/train/10/222/18.jpg जिसमें\r\n',
#  'HindiSeg/train/10/222/19.jpg वैचारिक\r\n',
#  'HindiSeg/train/10/222/20.jpg सॢवस\r\n',
#  'HindiSeg/train/10/222/21.jpg बूंदें\r\n',
#  'HindiSeg/train/10/222/22.jpg सोना\r\n',
#  'HindiSeg/train/10/222/23.jpg चुनने\r\n',
#  'HindiSeg/train/10/222/24.jpg मिठाइयां\r\n',
#  'HindiSeg/train/10/222/25.jpg गज-दो-गज\r\n',
#  'HindiSeg/train/10/222/26.jpg मात्राएं\r\n',
#  'HindiSeg/train/10/222/27.jpg सहनशील\r\n',
#  'HindiSeg/train/10/222/28.jpg जुटने\r\n',
#  'HindiSeg/train/10/222/29.jpg पल्लू\r\n',
#  'HindiSeg/train/10/222/30.jpg स्किल्स\r\n',
#  'HindiSeg/train/10/222/31.jpg शहीद\r\n',
#  'HindiSeg/train/10/222/32.jpg संभाले\r\n',
#  'HindiSeg/train/10/222/33.jpg युंजन्ति\r\n',
#  'HindiSeg/train/10/222/34.jpg अवस्था\r\n',
#  'HindiSeg/train/10/222/35.jpg भावों\r\n',
#  'HindiSeg/train/10/222/36.jpg प्रतिधारण\r\n',
#  'HindiSeg/train/10/222/37.jpg याज्ञवल्ल\r\n',
#  'HindiSeg/train/10/222/38.jpg आयी।\r\n',
#  'HindiSeg/train/10/222/39.jpg ऑफ़\r\n',
#  'HindiSeg/train/10/155/1.jpg ईश्वरीय\r\n',
#  'HindiSeg/train/10/155/2.jpg ॲप्लिकेशन\r\n',
#  'HindiSeg/train/10/155/3.jpg कैदियों\r\n',
#  'HindiSeg/train/10/155/4.jpg नव-उदारवाद\r\n',
#  'HindiSeg/train/10/155/5.jpg चीज\r\n',
#  'HindiSeg/train/10/155/6.jpg हुस्नी\r\n',
#  'HindiSeg/train/10/155/7.jpg स्विटज़रलैण्ड\r\n',
#  'HindiSeg/train/10/155/8.jpg हलके\r\n',
#  'HindiSeg/train/10/155/9.jpg लोप\r\n',
#  'HindiSeg/train/10/155/10.jpg रुग्णता\r\n',
#  'HindiSeg/train/10/155/11.jpg वसूलने\r\n',
#  'HindiSeg/train/10/155/12.jpg उपन्यासकार\r\n',
#  'HindiSeg/train/10/155/13.jpg करतार\r\n',
#  'HindiSeg/train/10/155/14.jpg डायरियाँ\r\n',
#  'HindiSeg/train/10/155/15.jpg मेरेसेदेस\r\n',
#  'HindiSeg/train/10/155/16.jpg बारें\r\n',
#  'HindiSeg/train/10/155/17.jpg फूटेगा\r\n',
#  'HindiSeg/train/10/155/18.jpg लुटिया\r\n',
#  'HindiSeg/train/10/155/19.jpg इन्वेस्ट\r\n',
#  'HindiSeg/train/10/155/20.jpg परिवारों\r\n',
#  'HindiSeg/train/10/155/21.jpg भीषोण\r\n',
#  'HindiSeg/train/10/155/22.jpg कांटा\r\n',
#  'HindiSeg/train/10/155/23.jpg भक्त\r\n',
#  'HindiSeg/train/10/155/24.jpg बचपन\r\n',
#  'HindiSeg/train/10/155/25.jpg टहल\r\n',
#  'HindiSeg/train/10/155/26.jpg निवासी-भागीरथपुरा\r\n',
#  'HindiSeg/train/10/155/27.jpg एनडीए\r\n',
#  'HindiSeg/train/10/155/28.jpg फ़ेंकना।\r\n',
#  'HindiSeg/train/10/155/29.jpg बढे।\r\n',
#  'HindiSeg/train/10/155/30.jpg नंदा\r\n',
#  'HindiSeg/train/10/155/31.jpg पाएगी\r\n',
#  'HindiSeg/train/10/155/32.jpg स्वम\r\n',
#  'HindiSeg/train/10/155/33.jpg पकिस्तान\r\n',
#  'HindiSeg/train/10/155/34.jpg हटान\r\n',
#  'HindiSeg/train/10/155/35.jpg आएगी।\r\n',
#  'HindiSeg/train/10/155/36.jpg आयत\r\n',
#  'HindiSeg/train/10/155/37.jpg रतनपुर\r\n',
#  'HindiSeg/train/10/164/1.jpg हांगकांग\r\n',
#  'HindiSeg/train/10/164/2.jpg लिलेश्वर\r\n',
#  'HindiSeg/train/10/164/3.jpg आयडीन\r\n',
#  'HindiSeg/train/10/164/4.jpg सिखावन\r\n',
#  'HindiSeg/train/10/164/5.jpg विकिपीडिया\r\n',
#  'HindiSeg/train/10/164/6.jpg याचिका\r\n',
#  'HindiSeg/train/10/164/7.jpg निहलानी\r\n',
#  'HindiSeg/train/10/164/8.jpg चिकित्सक\r\n',
#  'HindiSeg/train/10/164/9.jpg उषा\r\n',
#  'HindiSeg/train/10/164/10.jpg गोविंदम\r\n',
#  'HindiSeg/train/10/164/11.jpg हराकर\r\n',
#  'HindiSeg/train/10/164/12.jpg कहूँ\r\n',
#  'HindiSeg/train/10/164/13.jpg आर्किटेक्ट\r\n',
#  'HindiSeg/train/10/164/14.jpg वार्ष्णेय\r\n',
#  'HindiSeg/train/10/164/15.jpg काले\r\n',
#  'HindiSeg/train/10/164/16.jpg एजुकेशन\r\n',
#  'HindiSeg/train/10/164/17.jpg झटका\r\n',
#  'HindiSeg/train/10/164/18.jpg बोला-मैँने\r\n',
#  'HindiSeg/train/10/164/19.jpg चौरसिया\r\n',
#  'HindiSeg/train/10/164/20.jpg एनीमिज्म\r\n',
#  'HindiSeg/train/10/164/21.jpg बनते\r\n',
#  'HindiSeg/train/10/164/22.jpg बताए\r\n',
#  'HindiSeg/train/10/164/23.jpg घीसादास\r\n',
#  'HindiSeg/train/10/164/24.jpg कथानक\r\n',
#  'HindiSeg/train/10/164/25.jpg मांजने\r\n',
#  'HindiSeg/train/10/164/26.jpg सुनसरी\r\n',
#  'HindiSeg/train/10/164/27.jpg भगवत्स्वरूप\r\n',
#  'HindiSeg/train/10/164/28.jpg लम्हा\r\n',
#  'HindiSeg/train/10/164/29.jpg धृतराष्ट्र\r\n',
#  'HindiSeg/train/10/164/30.jpg वयोवृद्ध\r\n',
#  'HindiSeg/train/10/164/31.jpg बादलों\r\n',
#  'HindiSeg/train/10/164/32.jpg टोकती\r\n',
#  'HindiSeg/train/10/164/33.jpg मेक\r\n',
#  'HindiSeg/train/10/164/34.jpg वरदानों\r\n',
#  'HindiSeg/train/10/164/35.jpg युवा\r\n',
#  'HindiSeg/train/10/164/36.jpg बुद्ध\r\n',
#  'HindiSeg/train/10/25/1.jpg फ़ैसला\r\n',
#  'HindiSeg/train/10/25/2.jpg स्याही\r\n',
#  'HindiSeg/train/10/25/3.jpg दाता\r\n',
#  'HindiSeg/train/10/25/4.jpg जाटों\r\n',
#  'HindiSeg/train/10/25/5.jpg भई\r\n',
#  'HindiSeg/train/10/25/6.jpg पत्रकारों\r\n',
#  'HindiSeg/train/10/25/7.jpg फुलर\r\n',
#  'HindiSeg/train/10/25/8.jpg किकबॉक्सिंग\r\n',
#  'HindiSeg/train/10/25/9.jpg विम्बों\r\n',
#  'HindiSeg/train/10/25/10.jpg दुनियाभर\r\n',
#  'HindiSeg/train/10/25/11.jpg व्यंग्यात्मक\r\n',
#  'HindiSeg/train/10/25/12.jpg टॉम\r\n',
#  'HindiSeg/train/10/25/13.jpg सुनवाने\r\n',
#  'HindiSeg/train/10/25/14.jpg हों।\r\n',
#  'HindiSeg/train/10/25/15.jpg सोचकर\r\n',
#  'HindiSeg/train/10/25/16.jpg ही।\r\n',
#  'HindiSeg/train/10/25/17.jpg मुफ़ीद\r\n',
#  'HindiSeg/train/10/25/18.jpg टाकीज\r\n',
#  'HindiSeg/train/10/25/19.jpg हज़ारों\r\n',
#  'HindiSeg/train/10/25/20.jpg कांस्टेबल\r\n',
#  'HindiSeg/train/10/25/21.jpg ब्लडप्रेशर\r\n',
#  'HindiSeg/train/10/25/22.jpg गए\r\n',
#  'HindiSeg/train/10/25/23.jpg ४०\r\n',
#  'HindiSeg/train/10/25/24.jpg पदाधिकारियों\r\n',
#  'HindiSeg/train/10/25/25.jpg वाम\r\n',
#  'HindiSeg/train/10/25/26.jpg हिला\r\n',
#  'HindiSeg/train/10/25/27.jpg डालेंगे\r\n',
#  'HindiSeg/train/10/25/28.jpg प्रवर\r\n',
#  'HindiSeg/train/10/25/29.jpg बयानबाजी\r\n',
#  'HindiSeg/train/10/25/30.jpg बीकानेर\r\n',
#  'HindiSeg/train/10/25/31.jpg अलर्ट\r\n',
#  'HindiSeg/train/10/25/32.jpg उजड़\r\n',
#  'HindiSeg/train/10/25/33.jpg अनजाने\r\n',
#  'HindiSeg/train/10/25/34.jpg दवा\r\n',
#  'HindiSeg/train/10/25/35.jpg रहती\r\n',
#  'HindiSeg/train/10/25/36.jpg भेजी\r\n',
#  'HindiSeg/train/10/25/37.jpg नयी\r\n',
#  'HindiSeg/train/10/25/38.jpg लकडी\r\n',
#  'HindiSeg/train/10/25/39.jpg लहरों\r\n',
#  'HindiSeg/train/10/223/1.jpg पुडिय़ा\r\n',
#  'HindiSeg/train/10/223/2.jpg चिया\r\n',
#  'HindiSeg/train/10/223/3.jpg क्षति\r\n',
#  'HindiSeg/train/10/223/4.jpg बिंदू\r\n',
#  'HindiSeg/train/10/223/5.jpg चावेज\r\n',
#  'HindiSeg/train/10/223/6.jpg जातीय\r\n',
#  'HindiSeg/train/10/223/7.jpg श्रेष्ठ\r\n',
#  'HindiSeg/train/10/223/8.jpg पोंगी\r\n',
#  'HindiSeg/train/10/223/9.jpg दिक्दर्शन\r\n',
#  'HindiSeg/train/10/223/10.jpg घबराना\r\n',
#  'HindiSeg/train/10/223/11.jpg दही\r\n',
#  'HindiSeg/train/10/223/12.jpg बुलंदी\r\n',
#  'HindiSeg/train/10/223/13.jpg आकर्षक\r\n',
#  'HindiSeg/train/10/223/14.jpg तहसील\r\n',
#  'HindiSeg/train/10/223/15.jpg धरना\r\n',
#  'HindiSeg/train/10/223/16.jpg अड़चन\r\n',
#  'HindiSeg/train/10/223/17.jpg बीत\r\n',
#  'HindiSeg/train/10/223/18.jpg रहें\r\n',
#  'HindiSeg/train/10/223/19.jpg छांटकर\r\n',
#  'HindiSeg/train/10/223/20.jpg दिवंगत\r\n',
#  'HindiSeg/train/10/223/21.jpg हैरी\r\n',
#  'HindiSeg/train/10/223/22.jpg अर्ध्य\r\n',
#  'HindiSeg/train/10/223/23.jpg मशीनें\r\n',
#  'HindiSeg/train/10/223/24.jpg मानना।\r\n',
#  'HindiSeg/train/10/223/25.jpg विक्रमी\r\n',
#  'HindiSeg/train/10/223/26.jpg करणसापेक्षता\r\n',
#  'HindiSeg/train/10/223/27.jpg कृष्णवार्ता\r\n',
#  'HindiSeg/train/10/223/28.jpg नक्शा\r\n',
#  'HindiSeg/train/10/223/29.jpg नुस्खा\r\n',
#  'HindiSeg/train/10/223/30.jpg लमही।\r\n',
#  'HindiSeg/train/10/223/31.jpg निगेअिव\r\n',
#  'HindiSeg/train/10/223/32.jpg क्षुद्र\r\n',
#  'HindiSeg/train/10/223/33.jpg संकलक\r\n',
#  'HindiSeg/train/10/223/34.jpg आहट\r\n',
#  'HindiSeg/train/10/223/35.jpg पांडित्य\r\n',
#  'HindiSeg/train/10/223/36.jpg बीचिज\r\n',
#  'HindiSeg/train/10/223/37.jpg झुका\r\n',
#  'HindiSeg/train/10/223/38.jpg सीतापुर\r\n',
#  'HindiSeg/train/10/223/39.jpg फिल्म\r\n',
#  'HindiSeg/train/10/223/40.jpg भूतल\r\n',
#  'HindiSeg/train/10/223/41.jpg सच्चा\r\n',
#  'HindiSeg/train/10/297/1.jpg आह\r\n',
#  'HindiSeg/train/10/297/2.jpg चुराएंगे।\r\n',
#  'HindiSeg/train/10/297/3.jpg विदा\r\n',
#  'HindiSeg/train/10/297/4.jpg राजेश\r\n',
#  'HindiSeg/train/10/297/5.jpg मनोभाव\r\n',
#  ...]

# %%
lines = [x.strip() for x in lines] #

# %%
lines[0]
# Out:
# '\ufeff\r\n'

# %%
for line in lines:
    # ignore comment line
    if not line or line[0]=='#':
        continue

    lineSplit = line.strip().split(' ')
    if lineSplit[0] == '\ufeff':  # since reading first line give '\ufeff'
        continue

# %%
linesplit = lines[1].strip().split(' ')
linesplit[1]
# Out:
# 'हांगकांग'

# %%
text = ' '.join(linesplit[1])

# %%
'T'.join('APPLE')
# Out:
# 'ATPTPTLTE'

# %%
text
# Out:
# 'ह ा ं ग क ा ं ग'

# %%
text[2] == text[10]
# Out:
# True

# %%
arr = np.random.randn(2,3)
arr.shape
# Out:
# (2, 3)

# %%
arr = np.stack(arr,axis=0)

# %%
arr
# Out:
# array([[-0.43518377, -0.51228886, -1.663126  ],
#        [-0.09223251, -0.32015739,  0.20647132]])

# %%
str()
# Out:
# ''

# %%
str(' ')
# Out:
# ' '

# %%
class DataLoader:

    def __init__(self, filePath, batchSize, imgSize, maxTextLen):
        "loader for dataset at given location, preprocess images and text according to parameters"

        print(filePath)
        assert filePath[-1]=='/'  # should end with '/'
        print(filePath)
        self.dataAugmentation = False
        self.currIdx = 0
        self.batchSize = batchSize
        self.imgSize = imgSize
        self.samples = []
        # use your own path and trick to read the images with the txt file
        with codecs.open(filePath+'full.txt', "r", encoding='utf-8') as f:
            lines = f.readlines()
        lines = [x.strip() for x in lines] # removing newline
        chars = set()
        #print(lines[2]) # just check what in lines
        for line in lines:
            # ignore comment line
            if not line or line[0]=='#':
                continue

            lineSplit = line.strip().split(' ')

            if lineSplit[0] == '\ufeff':  # since reading first line give '\ufeff'
                continue

            fileName = filePath + lineSplit[0]

            # GT text are columns starting at 1
            gtText = self.truncateLabel(' '.join(lineSplit[1]), maxTextLen)
            chars = chars.union(set(list(gtText)))

            # check if image is not empty
            if not os.path.getsize(fileName):
                #bad_samples.append(lineSplit[0] + '.jpg')
                continue

            # put sample into list
            self.samples.append(Sample(gtText, fileName))



        # split into training and validation set: 90% - 10%
        splitIdx = int(0.90 * len(self.samples))
        self.trainSamples = self.samples[:splitIdx]
        self.validationSamples = self.samples[splitIdx:]

        # put words into lists
        self.trainWords = [x.gtText for x in self.trainSamples]
        self.validationWords = [x.gtText for x in self.validationSamples]

        # number of randomly chosen samples per epoch for training 
        self.numTrainSamplesPerEpoch = 25000 

        # start with train set
        self.trainSet()

        # list of all chars in dataset
        self.charList = sorted(list(chars))
        # print("TrainSet: {}, TestSet: {}".format(len(self.trainSamples), len(self.validationSamples)))
        # print("Total chars: ",len(self.charList))  # length: 109
        # charList = ''.join([str(x) for x in self.charList])
        # print(self.charList)
        # uncomment if new ground truth file is added or training from scratch
        # codecs.open('../model/charList.txt','w', encoding='utf-8').write(self.charList)

    def truncateLabel(self, text, maxTextLen):
        # ctc_loss can't compute loss if it cannot find a mapping between text label and input 
        # labels. Repeat letters cost double because of the blank symbol needing to be inserted.
        # If a too-long label is provided, ctc_loss returns an infinite gradient
        cost = 0
        for i in range(len(text)):
            if i != 0 and text[i] == text[i-1]:
                cost += 2
            else:
                cost += 1
            if cost > maxTextLen:
                return text[:i]
        return text

    def trainSet(self):
        "switch to randomly chosen subset of training set"
        self.dataAugmentation = True
        self.currIdx = 0
        random.shuffle(self.trainSamples)
        self.samples = self.trainSamples[:self.numTrainSamplesPerEpoch]

    def validationSet(self):
        "switch to validation set"
        self.dataAugmentation = False
        self.currIdx = 0
        self.samples = self.validationSamples

    def getIteratorInfo(self):
        "current batch index and overall number of batches"
        return (self.currIdx // self.batchSize + 1, len(self.samples) // self.batchSize)

    def hasNext(self):
        "iterator"
        return self.currIdx + self.batchSize <= len(self.samples)

    def getNext(self):
        "iterator"
        batchRange = range(self.currIdx, self.currIdx + self.batchSize)
        gtTexts = [self.samples[i].gtText for i in batchRange]
        imgs = [preprocess(cv2.imread(self.samples[i].filePath, cv2.IMREAD_GRAYSCALE), self.imgSize, self.dataAugmentation) for i in batchRange]
        self.currIdx += self.batchSize
        return Batch(gtTexts, imgs)

# %%
loader = DataLoader('../data/', 25, (128,32), 32)
# Out:
# ../data/
# ../data/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f0df2787ced8> in <module>
# ----> 1 loader = DataLoader('../data/', 25, (128,32), 32)
#
# <ipython-input-5-df11a5e8edba> in __init__(self, filePath, batchSize, imgSize, maxTextLen)
#      35
#      36             # check if image is not empty
# ---> 37             if not os.path.getsize(fileName):
#      38                 #bad_samples.append(lineSplit[0] + '.jpg')
#      39                 continue
#
# ~/anaconda3/lib/python3.7/genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/HindiSeg/train/10/259/1.jpg'
